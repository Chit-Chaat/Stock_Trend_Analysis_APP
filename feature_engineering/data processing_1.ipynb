# %%
# !pip install yfinance

# %%
import yfinance as yf

# %%
start_date = "2017-02-21"
end_date = "2021-02-21"
FB = yf.download( "FB", start=start_date, end=end_date)
# AAPL = yf.download( "AAPL", start=start_date, end=end_date)
# AMZN = yf.download( "AMZN", start=start_date, end=end_date)
# NFLX = yf.download( "NFLX", start=start_date, end=end_date)
# GOOG = yf.download( "GOOG", start=start_date, end=end_date)
# MSFT = yf.download( "MSFT", start=start_date, end=end_date)
# XLK = yf.download( "XLK", start=start_date, end=end_date)
# BOTZ = yf.download( "BOTZ", start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
FB
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-02-21  133.500000  133.910004  132.899994  133.720001  133.720001
# 2017-02-22  133.600006  136.789993  133.460007  136.119995  136.119995
# 2017-02-23  135.889999  136.119995  134.330002  135.360001  135.360001
# 2017-02-24  134.160004  135.619995  134.160004  135.440002  135.440002
# 2017-02-27  135.259995  137.179993  135.020004  136.410004  136.410004
# ...                ...         ...         ...         ...         ...
# 2021-02-12  270.519989  271.179993  268.339996  270.500000  270.500000
# 2021-02-16  270.799988  276.600006  270.049988  273.970001  273.970001
# 2021-02-17  271.239990  273.970001  269.579987  273.570007  273.570007
# 2021-02-18  269.570007  271.950012  266.029999  269.390015  269.390015
# 2021-02-19  269.859985  270.269989  260.149994  261.559998  261.559998
#
#               Volume
# Date
# 2017-02-21  14759100
# 2017-02-22  27360100
# 2017-02-23  18422500
# 2017-02-24  12625700
# 2017-02-27  14306700
# ...              ...
# 2021-02-12   9069100
# 2021-02-16  15417200
# 2021-02-17  12763200
# 2021-02-18  15249100
# 2021-02-19  25622600
#
# [1007 rows x 6 columns]

# %%
type(FB)
# Out:
# pandas.core.frame.DataFrame

# %%
FB_ticker = yf.Ticker("FB")

# %%
print(FB_ticker.info)
# Out:
# {'zip': '94025', 'sector': 'Communication Services', 'fullTimeEmployees': 58604, 'longBusinessSummary': "Facebook, Inc. develops products that enable people to connect and share with friends and family through mobile devices, personal computers, virtual reality headsets, and in-home devices worldwide. The company's products include Facebook that enables people to connect, share, discover, and communicate with each other on mobile devices and personal computers; Instagram, a community for sharing photos, videos, and private messages; Messenger, a messaging application for people to connect with friends, family, groups, and businesses across platforms and devices; and WhatsApp, a messaging application that is used by people and businesses to communicate in a private way. It also provides Facebook Reality Labs, an augmented and virtual reality product that help people feel connected, anytime, and anywhere. Facebook, Inc. was founded in 2004 and is headquartered in Menlo Park, California.", 'city': 'Menlo Park', 'phone': '650-543-4800', 'state': 'CA', 'country': 'United States', 'companyOfficers': [], 'website': 'http://investor.fb.com', 'maxAge': 1, 'address1': '1601 Willow Road', 'industry': 'Internet Content & Information', 'previousClose': 278.74, 'regularMarketOpen': 278.302, 'twoHundredDayAverage': 269.94318, 'trailingAnnualDividendYield': None, 'payoutRatio': 0, 'volume24Hr': None, 'regularMarketDayHigh': 284.5, 'navPrice': None, 'averageDailyVolume10Day': 23847812, 'totalAssets': None, 'regularMarketPreviousClose': 278.74, 'fiftyDayAverage': 270.32858, 'trailingAnnualDividendRate': None, 'open': 278.302, 'toCurrency': None, 'averageVolume10days': 23847812, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': None, 'exDividendDate': None, 'beta': 1.253521, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 277.77, 'priceHint': 2, 'currency': 'USD', 'trailingPE': 28.049553, 'regularMarketVolume': 16664212, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 805947506688, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 20527298, 'priceToSalesTrailing12Months': 9.3752985, 'dayLow': 277.77, 'ask': 282.56, 'ytdReturn': None, 'askSize': 900, 'volume': 16664212, 'fiftyTwoWeekHigh': 304.67, 'forwardPE': 20.90251, 'fromCurrency': None, 'fiveYearAvgDividendYield': None, 'fiftyTwoWeekLow': 150.83, 'bid': 282.75, 'tradeable': False, 'dividendYield': None, 'bidSize': 800, 'dayHigh': 284.5, 'exchange': 'NMS', 'shortName': 'Facebook, Inc.', 'longName': 'Facebook, Inc.', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '-14400000', 'quoteType': 'EQUITY', 'symbol': 'FB', 'messageBoardId': 'finmb_20765463', 'market': 'us_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 8.785, 'beta3Year': None, 'profitMargins': 0.33903998, 'enterpriseToEbitda': 19.102, '52WeekChange': 0.7054534, 'morningStarRiskRating': None, 'forwardEps': 13.54, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 2403970048, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'bookValue': 45.03, 'sharesShort': 27927478, 'sharesPercentSharesOut': 0.0098, 'fundFamily': None, 'lastFiscalYearEnd': 1609372800, 'heldPercentInstitutions': 0.79766, 'netIncomeToCommon': 29145999360, 'trailingEps': 10.09, 'lastDividendValue': None, 'SandP52WeekChange': 0.5131594, 'priceToBook': 6.2851434, 'heldPercentInsiders': 0.00632, 'nextFiscalYearEnd': 1672444800, 'mostRecentQuarter': 1609372800, 'shortRatio': 1.41, 'sharesShortPreviousMonthDate': 1613088000, 'floatShares': 2393979174, 'enterpriseValue': 755170541568, 'threeYearAverageReturn': None, 'lastSplitDate': None, 'lastSplitFactor': None, 'legalType': None, 'lastDividendDate': None, 'morningStarOverallRating': None, 'earningsQuarterlyGrowth': 0.527, 'dateShortInterest': 1615766400, 'pegRatio': 1.14, 'lastCapGain': None, 'shortPercentOfFloat': 0.0116, 'sharesS ...

# %%
for k, v in FB_ticker.info.items():
    print(str(k) + " --> " +  str(v))
# Out:
# zip --> 94025
# sector --> Communication Services
# fullTimeEmployees --> 58604
# longBusinessSummary --> Facebook, Inc. develops products that enable people to connect and share with friends and family through mobile devices, personal computers, virtual reality headsets, and in-home devices worldwide. The company's products include Facebook that enables people to connect, share, discover, and communicate with each other on mobile devices and personal computers; Instagram, a community for sharing photos, videos, and private messages; Messenger, a messaging application for people to connect with friends, family, groups, and businesses across platforms and devices; and WhatsApp, a messaging application that is used by people and businesses to communicate in a private way. It also provides Facebook Reality Labs, an augmented and virtual reality product that help people feel connected, anytime, and anywhere. Facebook, Inc. was founded in 2004 and is headquartered in Menlo Park, California.
# city --> Menlo Park
# phone --> 650-543-4800
# state --> CA
# country --> United States
# companyOfficers --> []
# website --> http://investor.fb.com
# maxAge --> 1
# address1 --> 1601 Willow Road
# industry --> Internet Content & Information
# previousClose --> 278.74
# regularMarketOpen --> 278.302
# twoHundredDayAverage --> 269.94318
# trailingAnnualDividendYield --> None
# payoutRatio --> 0
# volume24Hr --> None
# regularMarketDayHigh --> 284.5
# navPrice --> None
# averageDailyVolume10Day --> 23847812
# totalAssets --> None
# regularMarketPreviousClose --> 278.74
# fiftyDayAverage --> 270.32858
# trailingAnnualDividendRate --> None
# open --> 278.302
# toCurrency --> None
# averageVolume10days --> 23847812
# expireDate --> None
# yield --> None
# algorithm --> None
# dividendRate --> None
# exDividendDate --> None
# beta --> 1.253521
# circulatingSupply --> None
# startDate --> None
# regularMarketDayLow --> 277.77
# priceHint --> 2
# currency --> USD
# trailingPE --> 28.049553
# regularMarketVolume --> 16664212
# lastMarket --> None
# maxSupply --> None
# openInterest --> None
# marketCap --> 805947506688
# volumeAllCurrencies --> None
# strikePrice --> None
# averageVolume --> 20527298
# priceToSalesTrailing12Months --> 9.3752985
# dayLow --> 277.77
# ask --> 282.56
# ytdReturn --> None
# askSize --> 900
# volume --> 16664212
# fiftyTwoWeekHigh --> 304.67
# forwardPE --> 20.90251
# fromCurrency --> None
# fiveYearAvgDividendYield --> None
# fiftyTwoWeekLow --> 150.83
# bid --> 282.75
# tradeable --> False
# dividendYield --> None
# bidSize --> 800
# dayHigh --> 284.5
# exchange --> NMS
# shortName --> Facebook, Inc.
# longName --> Facebook, Inc.
# exchangeTimezoneName --> America/New_York
# exchangeTimezoneShortName --> EDT
# isEsgPopulated --> False
# gmtOffSetMilliseconds --> -14400000
# quoteType --> EQUITY
# symbol --> FB
# messageBoardId --> finmb_20765463
# market --> us_market
# annualHoldingsTurnover --> None
# enterpriseToRevenue --> 8.785
# beta3Year --> None
# profitMargins --> 0.33903998
# enterpriseToEbitda --> 19.102
# 52WeekChange --> 0.7054534
# morningStarRiskRating --> None
# forwardEps --> 13.54
# revenueQuarterlyGrowth --> None
# sharesOutstanding --> 2403970048
# fundInceptionDate --> None
# annualReportExpenseRatio --> None
# bookValue --> 45.03
# sharesShort --> 27927478
# sharesPercentSharesOut --> 0.0098
# fundFamily --> None
# lastFiscalYearEnd --> 1609372800
# heldPercentInstitutions --> 0.79766
# netIncomeToCommon --> 29145999360
# trailingEps --> 10.09
# lastDividendValue --> None
# SandP52WeekChange --> 0.5131594
# priceToBook --> 6.2851434
# heldPercentInsiders --> 0.00632
# nextFiscalYearEnd --> 1672444800
# mostRecentQuarter --> 1609372800
# shortRatio --> 1.41
# sharesShortPreviousMonthDate --> 1613088000
# floatShares --> 2393979174
# enterpriseValue --> 755170541568
# threeYearAverageReturn --> None
# lastSplitDate --> None
# lastSplitFactor --> None
# legalType --> None
# lastDividendDate --> None
# morningStarOverallRating --> None
# earningsQuarterlyGrowth --> 0.527
# dateShortInterest --> 1615766400
# pegRatio --> 1.14
# lastCapGain --> None
# shortPercentOfFloat --> 0.0116
# sharesShortPriorMonth --> 22866317
# impliedSharesOutstanding --> 2848290048
# category --> None
# fiveYearAverageReturn --> None
# regularMarketPrice --> 278.302
# logo_url --> https://logo.clearbit.com/investor.fb.com

# %%
FB_ticker.major_holders
# Out:
#         0                                      1
# 0   0.63%        % of Shares Held by All Insider
# 1  79.77%       % of Shares Held by Institutions
# 2  80.27%        % of Float Held by Institutions
# 3    3730  Number of Institutions Holding Shares

# %%
FB_ticker.institutional_holders
# Out:
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  182863853    2020-12-30  0.0760
# 1                     Blackrock Inc.  159655331    2020-12-30  0.0664
# 2                           FMR, LLC  123333773    2020-12-30  0.0513
# 3      Price (T.Rowe) Associates Inc  101745652    2020-12-30  0.0423
# 4           State Street Corporation   93308506    2020-12-30  0.0388
# 5    Capital International Investors   48682099    2020-12-30  0.0202
# 6  Capital Research Global Investors   48625748    2020-12-30  0.0202
# 7            Capital World Investors   40533105    2020-12-30  0.0169
# 8      Geode Capital Management, LLC   37068141    2020-12-30  0.0154
# 9                     Morgan Stanley   30382192    2020-12-30  0.0126
#
#          Value
# 0  49951090085
# 1  43611450215
# 2  33689853432
# 3  27792842300
# 4  25488151498
# 5  13298002162
# 6  13282609323
# 7  11072022961
# 8  10125533395
# 9   8299199566

# %%
# !pip install yfinance
# Out:
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22622 sha256=815b646528c1b606868e1fb7f2c0324a28700626a6eec8ebc6638192d7a5da1e
#   Stored in directory: C:\Users\AARON-PREDATOR\AppData\Local\pip\Cache\wheels\04\98\cc\2702a4242d60bdc14f48b4557c427ded1fe92aedf257d4565c
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.9-cp37-none-any.whl size=8373 sha256=43b6efa3c1faf7ba919fa54e0a292be83c55d161335a925194841a9c080938f7
#   Stored in directory: C:\Users\AARON-PREDATOR\AppData\Local\pip\Cache\wheels\37\fa\73\d492849e319038eb4d986f5152e4b19ffb1bc0639da84d2677
# Successfully built yfinance multitasking
# ...
#   Found existing installation: lxml 4.4.2
#     Uninstalling lxml-4.4.2:
#       Successfully uninstalled lxml-4.4.2
# ...

# %%
import yfinance as yf

# %%
start_date = "2017-02-21"
end_date = "2021-02-21"
FB = yf.download( "FB", start=start_date, end=end_date)
AAPL = yf.download( "AAPL", start=start_date, end=end_date)
AMZN = yf.download( "AMZN", start=start_date, end=end_date)
NFLX = yf.download( "NFLX", start=start_date, end=end_date)
GOOG = yf.download( "GOOG", start=start_date, end=end_date)
MSFT = yf.download( "MSFT", start=start_date, end=end_date)
XLK = yf.download( "XLK", start=start_date, end=end_date)
BOTZ = yf.download( "BOTZ", start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
FB
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-02-21  133.500000  133.910004  132.899994  133.720001  133.720001
# 2017-02-22  133.600006  136.789993  133.460007  136.119995  136.119995
# 2017-02-23  135.889999  136.119995  134.330002  135.360001  135.360001
# 2017-02-24  134.160004  135.619995  134.160004  135.440002  135.440002
# 2017-02-27  135.259995  137.179993  135.020004  136.410004  136.410004
# ...                ...         ...         ...         ...         ...
# 2021-02-12  270.519989  271.179993  268.339996  270.500000  270.500000
# 2021-02-16  270.799988  276.600006  270.049988  273.970001  273.970001
# 2021-02-17  271.239990  273.970001  269.579987  273.570007  273.570007
# 2021-02-18  269.570007  271.950012  266.029999  269.390015  269.390015
# 2021-02-19  269.859985  270.269989  260.149994  261.559998  261.559998
#
#               Volume
# Date
# 2017-02-21  14759100
# 2017-02-22  27360100
# 2017-02-23  18422500
# ...

# %%
type(FB)
# Out:
# pandas.core.frame.DataFrame

# %%
FB_ticker = yf.Ticker("FB")

# %%
print(FB_ticker.info)
# Out:
# {'zip': '94025', 'sector': 'Communication Services', 'fullTimeEmployees': 58604, 'longBusinessSummary': "Facebook, Inc. develops products that enable people to connect and share with friends and family through mobile devices, personal computers, virtual reality headsets, and in-home devices worldwide. The company's products include Facebook that enables people to connect, share, discover, and communicate with each other on mobile devices and personal computers; Instagram, a community for sharing photos, videos, and private messages; Messenger, a messaging application for people to connect with friends, family, groups, and businesses across platforms and devices; and WhatsApp, a messaging application that is used by people and businesses to communicate in a private way. It also provides Facebook Reality Labs, an augmented and virtual reality product that help people feel connected, anytime, and anywhere. Facebook, Inc. was founded in 2004 and is headquartered in Menlo Park, California
# ...

# %%
for k, v in FB_ticker.info.items():
    print(str(k) + " --> " +  str(v))
# Out:
# zip --> 94025
# sector --> Communication Services
# fullTimeEmployees --> 58604
# ...

# %%
FB_ticker.major_holders
# Out:
#         0                                      1
# 0   0.63%        % of Shares Held by All Insider
# 1  79.77%       % of Shares Held by Institutions
# 2  80.27%        % of Float Held by Institutions
# 3    3730  Number of Institutions Holding Shares

# %%
FB_ticker.institutional_holders
# Out:
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  182863853    2020-12-30  0.0760
# 1                     Blackrock Inc.  159655331    2020-12-30  0.0664
# 2                           FMR, LLC  123333773    2020-12-30  0.0513
# 3      Price (T.Rowe) Associates Inc  101745652    2020-12-30  0.0423
# 4           State Street Corporation   93308506    2020-12-30  0.0388
# 5    Capital International Investors   48682099    2020-12-30  0.0202
# 6  Capital Research Global Investors   48625748    2020-12-30  0.0202
# 7            Capital World Investors   40533105    2020-12-30  0.0169
# 8      Geode Capital Management, LLC   37068141    2020-12-30  0.0154
# 9                     Morgan Stanley   30382192    2020-12-30  0.0126
#
#          Value
# 0  49951090085
# 1  43611450215
# 2  33689853432
# 3  27792842300
# 4  25488151498
# 5  13298002162
# 6  13282609323
# 7  11072022961
# 8  10125533395
# 9   8299199566

# %%
FB.recommendations
